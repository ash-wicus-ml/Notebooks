# %%
# Load a dataset
import seaborn as sns
df = sns.load_dataset('planets')# Now let's group the data
groups = df.groupby('method').mean()
groups
# Out:
#                                  number  orbital_period      mass  \
# method
# Astrometry                     1.000000      631.180000       NaN
# Eclipse Timing Variations      1.666667     4751.644444  5.125000
# Imaging                        1.315789   118247.737500       NaN
# Microlensing                   1.173913     3153.571429       NaN
# Orbital Brightness Modulation  1.666667        0.709307       NaN
# Pulsar Timing                  2.200000     7343.021201       NaN
# Pulsation Timing Variations    1.000000     1170.000000       NaN
# Radial Velocity                1.721519      823.354680  2.630699
# Transit                        1.954660       21.102073  1.470000
# Transit Timing Variations      2.250000       79.783500       NaN
#
#                                   distance         year
# method
# Astrometry                       17.875000  2011.500000
# Eclipse Timing Variations       315.360000  2010.000000
# ...

# %%
# Highlight the Maximum values
groups.style.highlight_max(color = 'lightgreen')
# Out:
# <style type="text/css">
# #T_9d4a9_row1_col2, #T_9d4a9_row2_col1, #T_9d4a9_row3_col3, #T_9d4a9_row9_col0, #T_9d4a9_row9_col4 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9d4a9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d4a9_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_9d4a9_level0_col1" class="col_heading level0 col1" >orbital_period</th>
#       <th id="T_9d4a9_level0_col2" class="col_heading level0 col2" >mass</th>
#       <th id="T_9d4a9_level0_col3" class="col_heading level0 col3" >distance</th>
#       <th id="T_9d4a9_level0_col4" class="col_heading level0 col4" >year</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
# ...

# %%
from IPython.display import Image
from IPython.core.display import HTML 
PATH = "C:\\Users\\Dataframes - Highlights\\"
Image(filename = PATH + "1.JPG")

# %%
groups.style\
      .format('{:.2f}')\
      .highlight_max(color = 'lightgreen')\
      .highlight_min(color = 'coral')\
      .highlight_null(null_color='yellow')
# Out:
# C:\Users\ryan_\AppData\Local\Temp\ipykernel_11456\3172938405.py:5: FutureWarning: `null_color` is deprecated: use `color` instead
#   .highlight_null(null_color='yellow')
# <style type="text/css">
# #T_1169b_row0_col0, #T_1169b_row0_col3, #T_1169b_row4_col1, #T_1169b_row5_col4, #T_1169b_row6_col0, #T_1169b_row8_col2 {
#   background-color: coral;
# }
# #T_1169b_row0_col2, #T_1169b_row2_col2, #T_1169b_row3_col2, #T_1169b_row4_col2, #T_1169b_row5_col2, #T_1169b_row6_col2, #T_1169b_row6_col3, #T_1169b_row9_col2 {
#   background-color: yellow;
# }
# #T_1169b_row1_col2, #T_1169b_row2_col1, #T_1169b_row3_col3, #T_1169b_row9_col0, #T_1169b_row9_col4 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1169b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1169b_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_1169b_level0_col1" class="col_heading level0 col1" >orbital_period</th>
# ...

# %%
from IPython.display import Image
from IPython.core.display import HTML 
PATH = "C:\\Users\\Dataframes - Highlights\\"
Image(filename = PATH + "2.JPG")
