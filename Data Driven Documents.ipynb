# %%
# The advantage of d3 is its high performance, deeply customizable charts, and it works with web standards. 
# The name “D3” is short for Data-Driven Documents, which is a Javascript library for producing dynamic, 
# interactive data visualizations, it is fast, beautiful to see, and you can add all your creativity. 
# Furthermore, you don’t need any other technology than a browser to plot the graphs.

# %%
from d3blocks import D3Blocks

# Initialize
d3 = D3Blocks()

import warnings
warnings.filterwarnings('ignore')

import pandas as pd
from pandas import DataFrame


# Intitialise data of lists
data = [{'source': 'Arrivals', 'target':'Greece', 'weight':1590}, 
       {'source': 'Arrivals', 'target':'Spain', 'weight':1455},
       {'source': 'Arrivals', 'target':'France', 'weight':1345}, 
       {'source': 'Arrivals', 'target':'Iceland', 'weight':1100},
       {'source': 'Arrivals', 'target':'Iceland', 'weight':1850},
       {'source': 'Departures', 'target':'Greece', 'weight':2100}, 
       {'source': 'Departures', 'target':'Ireland', 'weight':1000},
       {'source': 'Departures', 'target':'America', 'weight':950}, 
       {'source': 'Departures', 'target':'Ireland', 'weight':1200},
       {'source': 'Departures', 'target':'Japan', 'weight':1050},]
df = pd.DataFrame(data)

df
# Out:
# [d3blocks] >INFO> Cleaning edge_properties and config parameters..
#        source   target  weight
# 0    Arrivals   Greece    1590
# 1    Arrivals    Spain    1455
# 2    Arrivals   France    1345
# 3    Arrivals  Iceland    1100
# 4    Arrivals  Iceland    1850
# 5  Departures   Greece    2100
# 6  Departures  Ireland    1000
# 7  Departures  America     950
# 8  Departures  Ireland    1200
# 9  Departures    Japan    1050

# %%
d3.d3graph(df, showfig=False)

# Color node on clustering
d3.D3graph.set_node_properties(color='cluster')


# Show the network graph
d3.D3graph.show()
# Out:
# [d3blocks] >INFO> Set directed=True to see the markers!
# [d3blocks] >INFO> Keep only edges with weight>0
# [d3blocks] >INFO> Number of unique nodes: 9
# [d3blocks] >INFO> Slider range is set to [949, 2950]
# [d3blocks] >INFO> Write to path: [C:\Users\ryans\AppData\Local\Temp\tmpkbn4g85o\d3graph.html]
# [d3blocks] >INFO> File already exists and will be overwritten: [C:\Users\ryans\AppData\Local\Temp\tmpkbn4g85o\d3graph.html]
# [d3blocks] >INFO> Number of unique nodes: 9
# [d3blocks] >INFO> Slider range is set to [949, 2950]
# [d3blocks] >INFO> Write to path: [C:\Users\ryans\AppData\Local\Temp\tmpwsl_b_c7\d3graph.html]
# [d3blocks] >INFO> File already exists and will be overwritten: [C:\Users\ryans\AppData\Local\Temp\tmpwsl_b_c7\d3graph.html]

# %%
from IPython.display import Image
from IPython.core.display import HTML 
PATH = "C:\\Users\\"
Image(filename = PATH + "1.JPG")

# %%
from d3blocks import D3Blocks

# Initialize
d3 = D3Blocks()


# Link settings
d3.sankey(df, link={"color": "source-target"})
# Out:
# [d3blocks] >INFO> Cleaning edge_properties and config parameters..
# [d3blocks] >INFO> Cleaning edge_properties and config parameters..
# [d3blocks] >INFO> Initializing [Sankey]
# [d3blocks] >INFO> filepath is set to [C:\Users\ryans\AppData\Local\Temp\d3blocks\sankey.html]
# [d3blocks] >INFO> Convert to Frame.
# [d3blocks] >INFO> Node properties are set.
# [d3blocks] >INFO> Edge properties are set.
# [d3blocks] >INFO> Open browser: C:\Users\ryans\AppData\Local\Temp\d3blocks\sankey.html

# %%
from IPython.display import Image
from IPython.core.display import HTML 
PATH = "C:\\Users\\"
Image(filename = PATH + "2.JPG")

# %%
from d3blocks import D3Blocks

# Initialize
d3 = D3Blocks()


# Link settings
d3.chord(df, filepath='chord_demo.html')
# Out:
# [d3blocks] >INFO> Cleaning edge_properties and config parameters..
# [d3blocks] >INFO> Cleaning edge_properties and config parameters..
# [d3blocks] >INFO> Initializing [Chord]
# [d3blocks] >INFO> filepath is set to [C:\Users\ryans\AppData\Local\Temp\d3blocks\chord_demo.html]
# [d3blocks] >INFO> Convert to Frame.
# [d3blocks] >INFO> Node properties are set.
# [d3blocks] >INFO> Set edge-opacity based on the [source] node-opacity.
# [d3blocks] >INFO> Set edge-colors based on the [source] node-color.
# [d3blocks] >INFO> Edge properties are set.
# [d3blocks] >INFO> Open browser: C:\Users\ryans\AppData\Local\Temp\d3blocks\chord_demo.html

# %%
from IPython.display import Image
from IPython.core.display import HTML 
PATH = "C:\\Users\\"
Image(filename = PATH + "3.JPG")
