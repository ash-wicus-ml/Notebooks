# %%
# Drop down controls are a great way to allow a user to dynamically interact with controls to customize a chart 
# in a variety of ways. Run the code below, click the drop down control, and witness the magic!

import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

us_cities = pd.read_csv(
    'https://raw.githubusercontent.com/plotly/datasets/master/us-cities-top-1k.csv'
)

traces = []
buttons = []
state_list = np.append('All_state', us_cities['State'].unique())
visible = state_list
for s in state_list:
    #print(s)
    if s == 'All_state':
        filtered_df = us_cities.copy()
    else:
        filtered_df = us_cities[us_cities['State'] == s]

    traces.append(go.Scattermapbox(
        lat=filtered_df['lat'],
        lon=filtered_df['lon'],
        mode='markers',
        visible=True if s == state_list[0] else False,
        customdata=filtered_df,
        hovertemplate='City: %{customdata[0]}<br>Population: %{customdata[2]}<extra></extra>',
        marker=go.scattermapbox.Marker(
            size=9,
            color='blue'
        )
    ))
    
    buttons.append(
        dict(
            method='update',
            label=s,
            args=[{'visible':list(visible==s)}],)
    )

fig = go.Figure(data=traces)
fig.update_layout(
    mapbox=dict(
        style='open-street-map',
        #accesstoken=mapbox_access_token,
        bearing=0,
        center=go.layout.mapbox.Center(
            lat=us_cities['lat'].mean(),
            lon=us_cities['lon'].mean(),
        ),
        zoom=3
    ),
    margin={'r':10, 't': 0, 'l': 0, 'b': 0}
)

fig.update_layout(
    # autosize=False,
    height=1000,
    showlegend=False,
    updatemenus=[
        dict(
            buttons=buttons,
            direction='down',
            x=0.05,
            y=1.0,
            xanchor='right',
            yanchor='bottom',
            font=dict(size=8)
        ),
    ]
)

fig.show()
# Out:
# <div>                            <div id="f8365600-e701-4b21-82f4-b67ff71a0bab" class="plotly-graph-div" style="height:1000px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8365600-e701-4b21-82f4-b67ff71a0bab")) {                    Plotly.newPlot(                        "f8365600-e701-4b21-82f4-b67ff71a0bab",                        [{"customdata":[["Marysville","Washington",63269,48.0517637,-122.1770818],["Perris","California",72326,33.7825194,-117.2286478],["Cleveland","Ohio",390113,41.49932,-81.6943605],["Worcester","Massachusetts",182544,42.262593200000005,-71.8022934],["Columbia","South Carolina",133358,34.0007104,-81.0348144],["Waterbury","Connecticut",109676,41.558152500000006,-73.0514965],["Eagan","Minnesota",65453,44.804132200000005,-93.1668858],["Southfield","Michigan",73006,42.473
# ...

# %%
from IPython.display import Image
from IPython.core.display import HTML 
PATH = "C:\\Users\\"
Image(filename = PATH + "CaptureNewYork.JPG")

# %%
from IPython.display import Image
from IPython.core.display import HTML 
PATH = "C:\\Users\\"
Image(filename = PATH + "CaptureWashington.JPG")

# %%
from IPython.display import Image
from IPython.core.display import HTML 
PATH = "C:\\Users\\"
Image(filename = PATH + "CaptureUnitedStates.JPG")

# %%
# The data source looks like this:
City,State,Population,lat,lon
Marysville,Washington,63269,48.0517637,-122.1770818
Perris,California,72326,33.7825194,-117.22864779999999
Cleveland,Ohio,390113,41.499320000000004,-81.6943605
Worcester,Massachusetts,182544,42.262593200000005,-71.8022934
Columbia,South Carolina,133358,34.0007104,-81.0348144
Waterbury,Connecticut,109676,41.558152500000006,-73.0514965
Eagan,Minnesota,65453,44.804132200000005,-93.1668858
Southfield,Michigan,73006,42.473368799999996,-83.2218731
Lafayette,Louisiana,124276,30.2240897,-92.0198427
Boise City,Idaho,214237,43.6187102,-116.2146068
Elkhart,Indiana,51265,41.6819935,-85.9766671
Buena Park,California,82882,33.867514299999996,-117.99811809999999
Marietta,Georgia,59089,33.952602,-84.5499327
Parker,Colorado,48608,39.5186002,-104.76136329999999
West Palm Beach,Florida,102436,26.7153424,-80.0533746
Salem,Massachusetts,42544,42.51954,-70.8967155
Aurora,Illinois,199963,41.7605849,-88.3200715
Leesburg,Virginia,47673,39.1156615,-77.5636015
Doral,Florida,50213,25.8195424,-80.3553302
Westminster,California,91739,33.7513419,-117.99399209999999
Lubbock,Texas,239538,33.5778631,-101.85516650000001
Overland Park,Kansas,181260,38.9822282,-94.6707917
Jackson,Mississippi,172638,32.298757300000005,-90.1848103

# %%
# here is another version of a drop down control dynamically plotting latitude and longitude coordinates of
# motor vehicle-related thefts around the city of Chicago.

import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import numpy as np


us_cities = pd.read_csv('C:\\users\\motor_vehicle_theft.csv')

traces = []
buttons = []
state_list = np.append('All_state', us_cities['Description'].unique())
visible = state_list
for s in state_list:
    #print(s)
    if s == 'All_state':
        filtered_df = us_cities.copy()
    else:
        filtered_df = us_cities[us_cities['Description'] == s]

    traces.append(go.Scattermapbox(
        lat=filtered_df['Lat'],
        lon=filtered_df['Lon'],
        mode='markers',
        visible=True if s == state_list[0] else False,
        customdata=filtered_df,
        hovertemplate='Primary_Type: %{customdata[0]}<br>Description: %{customdata[2]}<extra></extra>',
        marker=go.scattermapbox.Marker(
            size=9,
            color='red'
        )
    ))
    
    buttons.append(
        dict(
            method='update',
            label=s,
            args=[{'visible':list(visible==s)}],)
    )

fig = go.Figure(data=traces)
fig.update_layout(
    mapbox=dict(
        style='open-street-map',
        #accesstoken=mapbox_access_token,
        bearing=0,
        center=go.layout.mapbox.Center(
            lat=us_cities['Lat'].mean(),
            lon=us_cities['Lon'].mean(),
        ),
        zoom=3
    ),
    margin={'r':10, 't': 0, 'l': 0, 'b': 0}
)

fig.update_layout(
    # autosize=False,
    height=1000,
    showlegend=False,
    updatemenus=[
        dict(
            buttons=buttons,
            direction='down',
            x=0.05,
            y=1.0,
            xanchor='right',
            yanchor='bottom',
            font=dict(size=8)
        ),
    ]
)

fig.show()

# %%
from IPython.display import Image
from IPython.core.display import HTML 
PATH = "C:\\Users\\"
Image(filename = PATH + "CaptureChicago1.JPG")

# %%
from IPython.display import Image
from IPython.core.display import HTML 
PATH = "C:\\Users\\"
Image(filename = PATH + "CaptureChicago2.JPG")

# %%
from IPython.display import Image
from IPython.core.display import HTML 
PATH = "C:\\Users\\"
Image(filename = PATH + "CaptureChicago3.JPG")

# %%
# The data source looks like this:
Date	Block	Primary_Type	Description	Location_Description	Ward	Community_Area	Year	Lat	Lon
9/5/2015 14:30	037XX N BROADWAY	MOTOR VEHICLE THEFT	AUTOMOBILE	STREET	46	6	2015	41.95030761	-87.64906489
9/5/2015 16:00	015XX S HARDING AVE	MOTOR VEHICLE THEFT	AUTOMOBILE	DRIVEWAY - RESIDENTIAL	24	29	2015	41.86006173	-87.72377349
9/5/2015 1:00	021XX N MILWAUKEE AVE	MOTOR VEHICLE THEFT	AUTOMOBILE	STREET